# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
implementation_labels = dict()
implementation_labels[0] = 'Serial'
implementation_labels[1] = 'Naive'
implementation_labels[2] = 'Approximate'
implementation_labels[3] = 'Full'

# %%
# pre-processing steps
preprocessing = dict()
preprocessing[(0,0)] = 33.09
preprocessing[(0,1)] = 37.38
preprocessing[(0,2)] = 34.01
preprocessing[(0,3)] = 34.25
preprocessing[(0,4)] = 33.97
preprocessing[(1,0)] = 0
preprocessing[(1,1)] = 0
preprocessing[(1,2)] = 0
preprocessing[(1,3)] = 0
preprocessing[(1,4)] = 0
preprocessing[(2,0)] = 0
preprocessing[(2,1)] = 0
preprocessing[(2,2)] = 0
preprocessing[(2,3)] = 0
preprocessing[(2,4)] = 0
preprocessing[(3,0)] = 0
preprocessing[(3,1)] = 0
preprocessing[(3,2)] = 0
preprocessing[(3,3)] = 0
preprocessing[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in preprocessing.keys() if r[0]==i]
    runtime = [preprocessing[r] for r in preprocessing.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([preprocessing[r] for r in preprocessing.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Pre-processing')
plt.show()

# %%
# test.txt
test = dict()
test[(0,0)] = 0.79
test[(0,1)] = 0.89
test[(0,2)] = 0.85
test[(0,3)] = 0.85
test[(0,4)] = 0.85
test[(1,0)] = 0
test[(1,1)] = 0
test[(1,2)] = 0
test[(1,3)] = 0
test[(1,4)] = 0
test[(2,0)] = 0
test[(2,1)] = 0
test[(2,2)] = 0
test[(2,3)] = 0
test[(2,4)] = 0
test[(3,0)] = 0
test[(3,1)] = 0
test[(3,2)] = 0
test[(3,3)] = 0
test[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in test.keys() if r[0]==i]
    runtime = [test[r] for r in test.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([test[r] for r in test.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Spell-checking: test.txt (27 words, 4 errors)')
plt.show()

# %%
# tiny.txt
tiny = dict()
tiny[(0,0)] = 5.61
tiny[(0,1)] = 5.44
tiny[(0,2)] = 5.17
tiny[(0,3)] = 5.08
tiny[(0,4)] = 5.07
tiny[(1,0)] = 0
tiny[(1,1)] = 0
tiny[(1,2)] = 0
tiny[(1,3)] = 0
tiny[(1,4)] = 0
tiny[(2,0)] = 0
tiny[(2,1)] = 0
tiny[(2,2)] = 0
tiny[(2,3)] = 0
tiny[(2,4)] = 0
tiny[(3,0)] = 0
tiny[(3,1)] = 0
tiny[(3,2)] = 0
tiny[(3,3)] = 0
tiny[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in tiny.keys() if r[0]==i]
    runtime = [tiny[r] for r in tiny.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([tiny[r] for r in tiny.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Spell-checking: tiny.txt (209 words, 0 errors)')
plt.show()

# %%
# OCRsample.txt
OCRsample = dict()
OCRsample[(0,0)] = 15.70
OCRsample[(0,1)] = 15.52
OCRsample[(0,2)] = 15.78
OCRsample[(0,3)] = 16.56
OCRsample[(0,4)] = 15.19
OCRsample[(1,0)] = 0
OCRsample[(1,1)] = 0
OCRsample[(1,2)] = 0
OCRsample[(1,3)] = 0
OCRsample[(1,4)] = 0
OCRsample[(2,0)] = 0
OCRsample[(2,1)] = 0
OCRsample[(2,2)] = 0
OCRsample[(2,3)] = 0
OCRsample[(2,4)] = 0
OCRsample[(3,0)] = 0
OCRsample[(3,1)] = 0
OCRsample[(3,2)] = 0
OCRsample[(3,3)] = 0
OCRsample[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in OCRsample.keys() if r[0]==i]
    runtime = [OCRsample[r] for r in OCRsample.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([OCRsample[r] for r in OCRsample.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Spell-checking: OCRsample.txt (700 words, 175 errors)')
plt.show()

# %%
# yelp10reviews.txt
yelp10reviews = dict()
yelp10reviews[(0,0)] = 36.30
yelp10reviews[(0,1)] = 36.43
yelp10reviews[(0,2)] = 37.86
yelp10reviews[(0,3)] = 36.43
yelp10reviews[(0,4)] = 37.47
yelp10reviews[(1,0)] = 0
yelp10reviews[(1,1)] = 0
yelp10reviews[(1,2)] = 0
yelp10reviews[(1,3)] = 0
yelp10reviews[(1,4)] = 0
yelp10reviews[(2,0)] = 0
yelp10reviews[(2,1)] = 0
yelp10reviews[(2,2)] = 0
yelp10reviews[(2,3)] = 0
yelp10reviews[(2,4)] = 0
yelp10reviews[(3,0)] = 0
yelp10reviews[(3,1)] = 0
yelp10reviews[(3,2)] = 0
yelp10reviews[(3,3)] = 0
yelp10reviews[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in yelp10reviews.keys() if r[0]==i]
    runtime = [yelp10reviews[r] for r in yelp10reviews.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([yelp10reviews[r] for r in yelp10reviews.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Spell-checking: yelp10reviews.txt (1,467 words, 241 errors)')
plt.show()

# %%
# yelp100reviews.txt
yelp100reviews = dict()
yelp100reviews[(0,0)] = 314.55
yelp100reviews[(0,1)] = 326.73
yelp100reviews[(0,2)] = 321.48
yelp100reviews[(0,3)] = 325.32
yelp100reviews[(0,4)] = 330.63
yelp100reviews[(1,0)] = 0
yelp100reviews[(1,1)] = 0
yelp100reviews[(1,2)] = 0
yelp100reviews[(1,3)] = 0
yelp100reviews[(1,4)] = 0
yelp100reviews[(2,0)] = 0
yelp100reviews[(2,1)] = 0
yelp100reviews[(2,2)] = 0
yelp100reviews[(2,3)] = 0
yelp100reviews[(2,4)] = 0
yelp100reviews[(3,0)] = 0
yelp100reviews[(3,1)] = 0
yelp100reviews[(3,2)] = 0
yelp100reviews[(3,3)] = 0
yelp100reviews[(3,4)] = 0

plt.figure(figsize=(8,5))
for i in [1, 2, 3]:
    impl = [r[0] for r in yelp100reviews.keys() if r[0]==i]
    runtime = [yelp100reviews[r] for r in yelp100reviews.keys() if r[0]==i]
    plt.plot(impl, runtime, 'o-')
plt.axhline(y=np.mean([yelp100reviews[r] for r in yelp100reviews.keys() if r[0]==0]), 
            color='k', linewidth=2, linestyle='--', label=implementation_labels[0])
plt.xlim(xmin=0, xmax=4)
plt.xticks([1, 2, 3], [implementation_labels[1], implementation_labels[2], implementation_labels[3]])
plt.legend(loc='best')
plt.ylabel('Runtime')
plt.title('Spell-checking: yelp100reviews.txt (12,029 words, 1,761 errors)')
plt.show()
